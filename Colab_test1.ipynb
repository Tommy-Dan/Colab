# %% [markdown]
# <a href="https://colab.research.google.com/github/Tommy-Dan/Colab/blob/main/Colab_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is this

# %%
print("Hello python3")
# Out:
# Hello python3

# %%
# %colors dark
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/basic.py:343: UserWarning: Error changing shell color schemes.
# The 'colors' trait of a Shell instance expected any of ['Neutral', 'NoColor', 'LightBG', 'Linux'] (case-insensitive), not the str 'dark'.
#   color_switch_err('shell')
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/basic.py:350: UserWarning: Error changing exception color schemes.
# Unrecognized color scheme: dark
# Valid schemes: ['NoColor', 'Linux', 'LightBG', 'Neutral', '']
#   color_switch_err('exception')
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/basic.py:357: UserWarning: Error changing object inspector color schemes.
# Unrecognized color scheme: dark
# Valid schemes: ['NoColor', 'Linux', 'LightBG', 'Neutral', '']
#   color_switch_err('object inspector')

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0
